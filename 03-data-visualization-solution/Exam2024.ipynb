# %% [markdown]
# ## Question 1

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#A hotel wants to optimize the revenue from its room bookings. The hotel has a total of 200 rooms. The variable cost to maintian each room per night varies with occupancy

#$50 per room for up to 60 rooms
#$40 per room for more than 60 rooms and up to 150 rooms
#$30 per room for more than 150 rooms

#Additionally, if the number of bookings exceeds 100 rooms, the hotel incurs an extra administrative fee of $20.

#The demand function for room bookings is given by D(p) = [1000-2.2p], where p represents the selling price (in dollars) of each room per night.
#The floor function [.] ensures integer demand levels by rounding down (you can achieve this by casting to (int) in Python).

#Tasks:

#a. Formulate expressions and implement i Python
    #1. Demand function: Implement a python function demand(p) to calculate the number of rooms booked based on the selling price.
    #2. Revenue function: Implement a python function revenue(p) to calculate the total revenue
    #3. Total cost function: Implement a Python function total_cost(p) to calculate the total cost, considering the variable cost tiers and the
    #extra administrative fee if bookings exceed 100 rooms.

#b. Profit calculation: Implement a Python function profit(p) to calculate the profit based on the total revenue and total cost

# %%
#a
#1a: Demand function
def demand(p):
    """
    Calculating the number of rooms booked depending on what the price is. The base is a 1000 rooms, and 
    then the demand decreased by 2.2 rooms for every 1 dollar increase in price
    """
    return int(1000- 2.2*p) #i use int to round down the demand level

# %%
#2a Revenue function
def revenue(p):
    """
    Calculating the total revenue based on the demand function
    """
    return int(1000 - 2.2*p) * p
    #The demand function decides the number of rooms that are booked depending on the price. 
    #I then multiply the demand of the rooms by the price to get the revenue

# %%
#3a Total cost function
def total_cost(p):
    """
    Calculating the total cost based on the number of rooms booked, considering the variable costs
    """
    #I use the above specified demand function to determine how many rooms are booked, which affect the variable fee
    if demand(p) <= 60:
        return demand(p) * 50 #If the demand for rooms is less than or 60 rooms, the variable cost fee is 50 per room.
    elif demand(p) <= 150:
        return demand(p) * 40 #if the demand for rooms is less than or equal to 150 rooms, the variable cost fee is 40 per room
    elif demand(p) > 150:
        return demand(p) * 30 #if the demand for rooms is more than 150 rooms, the variable cost fee is 30 per room
        
    administrative_fee = 0 #I initalize the administrative fee to start at 0, so there's no cost if the demand is less than 100 rooms
    if demand(p) > 100:
        administrative_fee += 20 #The administrative incurs if the demand is above 100 rooms

    total_cost = total_cost(p) + administrative_fee #the total cost comes from the total_cost function and the possible administrative fee

    return total_cost

# %%
#b Profit calculation

# %% [markdown]
# ## Question 2

# %% [markdown]
# ## Question 3

# %% [markdown]
# ## Question 4

# %% [markdown]
# ## Question 5
